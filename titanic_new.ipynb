# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x="Pclass",y="Age",data=df,linewidth=4)

# %%
class1=df[df["Pclass"]==1]
class2=df[df["Pclass"]==2]
class3=df[df["Pclass"]==3]
c1=float(class1["Age"].mean())
c2=float(class1["Age"].mean())
c3=float(class1["Age"].mean())
print("Class A:{a},Class B:{b},Class C:{c}".format(a=c1,b=c2,c=c3))
# Out:
# Class A:38.233440860215055,Class B:38.233440860215055,Class C:38.233440860215055

# %%
def age_fill(df):
    Age=df[0]
    Pclass=df[1]
    if pd.isnull(Age):
        if Pclass==1:
            return c1
        elif Pclass==2:
            return c2
        else:
            return c3
    else:
        return Age

# %%
df["Age"]=df[["Age","Pclass"]].apply(age_fill,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
agesplit = [0,12,18,40,60,75,90]
agestatus = ["Child","Adolscence","Adult","Middle Age","Senior","Very senior"]

df['agegroup']=pd.cut(df.Age,agesplit,labels=agestatus)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked agegroup
# 0      0         A/5 21171   7.2500   NaN        S    Adult
# 1      0          PC 17599  71.2833   C85        C    Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Adult
# 3      0            113803  53.1000  C123        S    Adult

# %%
a=df[((df["Age"]<110)&(df["Age"]>68))]
a.sort_values("Age",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked     agegroup
# 630  male  80.0      0      0       27042  30.0000   A23        S  Very senior
# 851  male  74.0      0      0      347060   7.7750   NaN        S       Senior
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C       Senior
# ...

# %%
plt.figure(figsize=(13,5))
sns.countplot(x='agegroup',data=df,hue="Survived")
plt.legend(loc=1)
plt.tight_layout()

# %%
sns.countplot(x="Sex",hue="Survived",data=df)

# %%
df["Survived"].replace(1,"Survived",inplace=True)
df["Survived"].replace(0,"Not-Survived",inplace=True)
df.head(3)
# Out:
#    PassengerId      Survived  Pclass  \
# 0            1  Not-Survived       3
# 1            2      Survived       1
# 2            3      Survived       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked agegroup
# 0      0         A/5 21171   7.2500   NaN        S    Adult
# 1      0          PC 17599  71.2833   C85        C    Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Adult

# %%
plt.figure(figsize=(13,5))
sns.countplot(x="Embarked",data=df,hue="Survived")
plt.legend(loc="best")
print("c=Chebourge:")
# Out:
# c=Chebourge:

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x="Pclass",y="Age",data=df)
sns.swarmplot(x="Pclass",y="Age",data=df,color=".10")

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="Age",data=df,color="b",linewidth=4)
sns.swarmplot(x="Age",data=df,color="y")

# %%
rs
